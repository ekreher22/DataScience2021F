# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('bachelorette.csv')
df
# Out:
#              SHOW  SEASON     CONTESTANT ELIMINATION-1 ELIMINATION-2  \
# 0            SHOW  SEASON             ID             1             2
# 1    Bachelorette      13     13_BRYAN_A            R1           NaN
# 2    Bachelorette      13     13_PETER_K           NaN             R
# 3    Bachelorette      13      13_ERIC_B           NaN           NaN
# 4    Bachelorette      13      13_DEAN_U           NaN             R
# ..            ...     ...            ...           ...           ...
# 916      Bachelor      01  01_KRISTINA_X             E           NaN
# 917      Bachelor      01      01_LISA_X             E           NaN
# 918      Bachelor      01     01_PAULA_X             E           NaN
# 919      Bachelor      01    01_RACHEL_X             E           NaN
# 920      Bachelor      01     01_WENDI_X             E           NaN
#
#     ELIMINATION-3 ELIMINATION-4 ELIMINATION-5 ELIMINATION-6 ELIMINATION-7  \
# 0               3             4             5             6             7
# 1             NaN             R             R           NaN             R
# 2             NaN           NaN           NaN             R             R
# 3               R           NaN           NaN             R             R
# 4             NaN             R           NaN           NaN             R
# ..            ...           ...           ...           ...           ...
# 916           NaN           NaN           NaN           NaN           NaN
# 917           NaN           NaN           NaN           NaN           NaN
# 918           NaN           NaN           NaN           NaN           NaN
# 919           NaN           NaN           NaN           NaN           NaN
# 920           NaN           NaN           NaN           NaN           NaN
#
#      ... DATES-1 DATES-2 DATES-3 DATES-4 DATES-5 DATES-6 DATES-7 DATES-8  \
# 0    ...       1       2       3       4       5       6       7       8
# 1    ...     NaN     NaN      D6     D13      D1      D7      D1      D1
# 2    ...     NaN      D1      D6     D13      D9      D7      D1      D1
# 3    ...     NaN     D10      D8     D13      D9      D1      D3      D1
# 4    ...     NaN      D8      D8      D1      D9      D7      D1      D1
# ..   ...     ...     ...     ...     ...     ...     ...     ...     ...
# 916  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 917  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 918  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 919  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 920  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#     DATES-9 DATES-10
# 0         9       10
# 1        D1       D1
# 2        D1       D1
# 3        D1      NaN
# 4       NaN      NaN
# ..      ...      ...
# 916     NaN      NaN
# 917     NaN      NaN
# 918     NaN      NaN
# 919     NaN      NaN
# 920     NaN      NaN
#
# [921 rows x 23 columns]

# %%
#seperate bachelor and bachelorette

# %%
grouped = df.groupby(df.SHOW)
bachelorette = grouped.get_group("Bachelorette")
bachelor = grouped.get_group("Bachelor")

# %%
#what season has the most eliminated contestants on the first night
#do bar graph with season as x and num of ppl eliminated

# %%
df = bachelor.loc[(bachelor['ELIMINATION-1']== 'E'),['SEASON','ELIMINATION-1']]
df.groupby('SEASON').count()
# Out:
#         ELIMINATION-1
# SEASON
# 01                 10
# 02                  9
# 03                 10
# 04                 10
# 05                  9
# 06                 10
# 07                  8
# 08                 13
# 09                 15
# 10                 10
# 11                 10
# 12                 10
# 13                 10
# 14                 10
# 15                 10
# 16                  7
# 17                  7
# 18                  9
# 19                  8
# 20                  7
# 21                  8

# %%
#how many seasons did the person who got the first impresion rose won the whole thing

# %%
bachelor.loc[(bachelor['ELIMINATION-1']== 'R1') & (bachelor['ELIMINATION-10'] == 'W'),['SEASON','CONTESTANT']]
# Out:
#     SEASON      CONTESTANT
# 352     21    21_VANESSA_G
# 471     17  17_CATHERINE_G

# %%
bachelorette.loc[(bachelorette['ELIMINATION-1']== 'R1') & (bachelorette['ELIMINATION-10'] == 'W'),['SEASON','CONTESTANT']]
# Out:
#     SEASON   CONTESTANT
# 1       13   13_BRYAN_A
# 33      12  12_JORDAN_R
# 191     06  06_ROBERT_M

# %%
bachelor.loc[bachelor['ELIMINATION-1']== 'R1']
# Out:
#          SHOW SEASON      CONTESTANT ELIMINATION-1 ELIMINATION-2  \
# 352  Bachelor     21    21_VANESSA_G            R1           NaN
# 390  Bachelor     20     20_OLIVIA_C            R1             R
# 417  Bachelor     19      19_BRITT_N            R1           NaN
# 448  Bachelor     18   18_SHARLEEN_J            R1           NaN
# 471  Bachelor     17  17_CATHERINE_G            R1           NaN
# 473  Bachelor     17     17_ASHLEE_F            R1           NaN
# 474  Bachelor     17    17_DESIREE_H            R1             R
# 476  Bachelor     17     17_TIERRA_L            R1           NaN
# 478  Bachelor     17      17_SLEMA_A            R1           NaN
# 479  Bachelor     17      17_SARAH_H            R1             R
# 480  Bachelor     17      17_ROBYN_H            R1           NaN
# 481  Bachelor     17     17_JACKIE_[            R1           NaN
# 483  Bachelor     17     17_LESLIE_H            R1           NaN
# 487  Bachelor     17     17_BROOKE_B            R1             E
# 488  Bachelor     17      17_DIANA_W            R1             E
# 489  Bachelor     17      17_LATIE_L            R1            EQ
# 499  Bachelor     16     16_LINDZI_C            R1           NaN
# 534  Bachelor     15     15_ASHLEY_S            R1           NaN
# 556  Bachelor     14     14_TENLEY_M            R1           NaN
# 589  Bachelor     13      13_NIKKI_K            R1           NaN
# 609  Bachelor     12     12_AMANDA_R            R1           NaN
# 634  Bachelor     11      11_JENNI_C            R1           NaN
# 667  Bachelor     10  10_STEPHANIE_T            R1             R
# 687  Bachelor     09       09_LISA_B            R1             R
# 741  Bachelor     07     07_Sarah W.            R1             R
# 747  Bachelor     07        07_Kerry            R1             E
# 796  Bachelor     05      05_TRISH_S            R1           NaN
#
#     ELIMINATION-3 ELIMINATION-4 ELIMINATION-5 ELIMINATION-6 ELIMINATION-7  \
# 352             R           NaN           NaN           NaN           NaN
# 390           NaN           NaN             R            ED           NaN
# 417           NaN           NaN             R             R             E
# 448           NaN             R           NaN             R            EQ
# 471           NaN           NaN           NaN             R           NaN
# 473             R           NaN           NaN           NaN           NaN
# 474           NaN           NaN           NaN             R           NaN
# 476           NaN             R             R           NaN            EU
# 478           NaN             R           NaN             E           NaN
# 479           NaN           NaN           NaN            EU           NaN
# 480           NaN           NaN             E           NaN           NaN
# 481           NaN           NaN            ED           NaN           NaN
# 483           NaN            ED           NaN           NaN           NaN
# 487           NaN           NaN           NaN           NaN           NaN
# 488           NaN           NaN           NaN           NaN           NaN
# 489           NaN           NaN           NaN           NaN           NaN
# 499             R           NaN           NaN             R           NaN
# 534             R           NaN            ED           NaN           NaN
# 556           NaN             R           NaN           NaN           NaN
# 589           NaN            ED           NaN           NaN           NaN
# 609           NaN             R           NaN           NaN             E
# 634           NaN             R           NaN           NaN           NaN
# 667           NaN             E           NaN           NaN           NaN
# 687           NaN           NaN           NaN             E           NaN
# 741           NaN           NaN           NaN             E           NaN
# 747           NaN           NaN           NaN           NaN           NaN
# 796           NaN           NaN             E           NaN           NaN
#
#      ... DATES-1 DATES-2 DATES-3 DATES-4 DATES-5 DATES-6 DATES-7 DATES-8  \
# 352  ...     NaN     D12      D1     D13     D10      D6      D1      D1
# 390  ...     NaN      D6     D12     D12      D9      D2     NaN     NaN
# 417  ...     NaN     D11     D12      D6      D1      D6      D3     NaN
# 448  ...     NaN     NaN     D10      D1      D9      D6      D1     NaN
# 471  ...     NaN     D13     D12      D8      D8      D1      D3      D1
# 473  ...     NaN     NaN      D1      D8      D8      D7      D1      D1
# 474  ...     NaN      D1     D12     NaN      D8      D1      D3      D1
# 476  ...     NaN     D13     D12      D8      D2      D7     NaN     NaN
# 478  ...     NaN     D13     NaN      D1      D8      D7     NaN     NaN
# 479  ...     NaN      D1     NaN      D8      D8      D7     NaN     NaN
# 480  ...     NaN     D13     D12      D8      D8     NaN     NaN     NaN
# 481  ...     NaN     NaN     D12      D8      D2     NaN     NaN     NaN
# 483  ...     NaN     NaN     D12      D1     NaN     NaN     NaN     NaN
# 487  ...     NaN     D13     NaN     NaN     NaN     NaN     NaN     NaN
# 488  ...     NaN     D13     NaN     NaN     NaN     NaN     NaN     NaN
# 489  ...     NaN     D13     NaN     NaN     NaN     NaN     NaN     NaN
# 499  ...     NaN     NaN      D1      D8      D9      D6      D1      D1
# 534  ...     NaN     NaN      D1      D9      D2     NaN     NaN     NaN
# 556  ...     NaN     NaN      D8      D6      D1      D1      D1      D1
# 589  ...     NaN      D8      D8      D2     NaN     NaN     NaN     NaN
# 609  ...     NaN      D8     D10      D1      D4      D1      D1     NaN
# 634  ...     NaN      D7      D6      D1      D4      D1      D1      D1
# 667  ...     NaN      D1      D5      D4     NaN     NaN     NaN     NaN
# 687  ...     NaN      D1      D6      D4      D1      D1     NaN     NaN
# 741  ...      D9      D1      D6      D5      D1      D1     NaN     NaN
# 747  ...      D6     D10     NaN     NaN     NaN     NaN     NaN     NaN
# 796  ...     NaN      D1      D2      D3      D1     NaN     NaN     NaN
#
#     DATES-9 DATES-10
# 352      D1       D1
# 390     NaN      NaN
# 417     NaN      NaN
# 448     NaN      NaN
# 471      D1       D1
# 473      D1      NaN
# 474     NaN      NaN
# 476     NaN      NaN
# 478     NaN      NaN
# 479     NaN      NaN
# 480     NaN      NaN
# 481     NaN      NaN
# 483     NaN      NaN
# 487     NaN      NaN
# 488     NaN      NaN
# 489     NaN      NaN
# 499      D1       D1
# 534     NaN      NaN
# 556     NaN      NaN
# 589     NaN      NaN
# 609     NaN      NaN
# 634     NaN      NaN
# 667     NaN      NaN
# 687     NaN      NaN
# 741     NaN      NaN
# 747     NaN      NaN
# 796     NaN      NaN
#
# [27 rows x 23 columns]

# %%
#which season had the most unscheduled eliminations

# %%
#bachelor.loc[(bachelor['S'])]
#crimes.groupby('SEASON').count()
#bachelor.loc[(bachelor['SEASON'] == 1) & (bachelor['ELIMINATION-3'] == 'EU')]
bachelor[bachelor.contains('EU')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-1b125db5062a> in <module>
#       2 #crimes.groupby('SEASON').count()
#       3 #bachelor.loc[(bachelor['SEASON'] == 1) & (bachelor['ELIMINATION-3'] == 'EU')]
# ----> 4 bachelor[bachelor.contains('EU')]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'contains'
